# %%
import json
from collections import Counter

from sentence_splitter import SentenceSplitter

# %%
import sys
sys.path.append('../src')  # Add src to Python path

from loader_local import load_isic_nace_master, process_and_save_data
from aligner_util_local import copy_files_with_rename

# %% [markdown]
# # Ensure no pair duplicates

# %%
with open('../data/web-optim/correspondence.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Convert lists to tuples (since lists aren't hashable)
data_tuples = [tuple(pair) for pair in data]

# Count occurrences
counts = Counter(data_tuples)

# Find duplicates
duplicates = {pair: count for pair, count in counts.items() if count > 1}

if duplicates:
    print("Duplicate pairs found:")
    for pair, count in duplicates.items():
        print(f"  {list(pair)} appears {count} times")
else:
    print("No duplicate pairs found!")
# Out:
# No duplicate pairs found!

# %% [markdown]
# # Make the input data for SentAlign

# %%
isic_df, nace_df = load_isic_nace_master()

# %%
isic_df['ISIC5_Desc2'] = isic_df['ISIC5_Section'] + ' ' + isic_df['ISIC5_Title'] + '\n' + isic_df['ISIC5_Desc'].fillna('')
isic_df.head()
# Out:
#   ISIC5_Section CAT ISIC5_Code  \
# 0             A   A          A
# 1           A01   A         01
# 2          A011   A        011
# 3         A0111   A       0111
# 4         A0112   A       0112
#
#                                          ISIC5_Title  \
# 0                  Agriculture, forestry and fishing
# 1  Crop and animal production, hunting and relate...
# 2                     Growing of non-perennial crops
# 3  Growing of cereals (except rice), leguminous c...
# 4                                    Growing of rice
#
#                                           ISIC5_Desc  \
# 0  This section includes the exploitation of vege...
# 1  This division includes two basic activities, n...
# 2  This group includes the growing of non-perenni...
# 3  This class includes all forms of growing of ce...
# 4          This class includes:\n- growing of rice\n
#
#                                          ISIC5_Desc2
# 0  A Agriculture, forestry and fishing\nThis sect...
# 1  A01 Crop and animal production, hunting and re...
# 2  A011 Growing of non-perennial crops\nThis grou...
# 3  A0111 Growing of cereals (except rice), legumi...
# 4  A0112 Growing of rice\nThis class includes:\n-...

# %%
process_and_save_data(
    dataframe=isic_df,
    output_dir='../data/txt-isic5',
    code_column='ISIC5_Section',
    desc_column='ISIC5_Desc2'
)

# %%
nace_df['ACODE'] = nace_df.apply(lambda row: row['CAT'] + row['CODE'] if len(row['CODE']) > 1 else row['CAT'], axis=1)
nace_df['DESC2'] = nace_df['ACODE'] + ' ' + nace_df['HEADING'] + '\n' + nace_df['DESC'].fillna('')
nace_df.head()
# Out:
#      ID CAT   CODE                                            HEADING  \
# 0     A   A      A                  AGRICULTURE, FORESTRY AND FISHING
# 1    01   A     01  Crop and animal production, hunting and relate...
# 2   011   A   01.1                     Growing of non-perennial crops
# 3  0111   A  01.11  Growing of cereals, other than rice, leguminou...
# 4  0112   A  01.12                                    Growing of rice
#
#   PARENT_ID PARENT_CODE  LEVEL  \
# 0       NaN         NaN      1
# 1         A           A      2
# 2        01          01      3
# 3       011        01.1      4
# 4       011        01.1      4
#
#                                                 DESC   ACODE  \
# 0  This section includes the exploitation of vege...       A
# 1  This division includes two basic activities, n...     A01
# 2  This group includes the growing of non-perenni...   A01.1
# 3  This class includes all forms of growing of ce...  A01.11
# 4            This class includes:\n- growing of rice  A01.12
#
#                                                DESC2
# 0  A AGRICULTURE, FORESTRY AND FISHING\nThis sect...
# 1  A01 Crop and animal production, hunting and re...
# 2  A01.1 Growing of non-perennial crops\nThis gro...
# 3  A01.11 Growing of cereals, other than rice, le...
# 4  A01.12 Growing of rice\nThis class includes:\n...

# %%
process_and_save_data(
    dataframe=nace_df,
    output_dir='../data/txt-nace21',
    code_column='ACODE',
    desc_column='DESC2'
)

# %%
copy_files_with_rename(
    cor_data=data,
    isic_dir='../data/txt-isic5/',
    nace_dir='../data/txt-nace21/',
    isic_dest='../data/input-sa/isic5/',
    nace_dest='../data/input-sa/nace21/'
)
