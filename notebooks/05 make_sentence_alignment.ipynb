# %% [markdown]
# # Explanation
# - this notebook is run from Colab
# - I move the input through GUI, so it is not reflected here

# %%
# !rm -r SentAlign

# %%
# !git clone https://github.com/mdmahendri/SentAlign.git
# Out:
# Cloning into 'SentAlign'...
# remote: Enumerating objects: 233, done.
# remote: Counting objects: 100% (233/233), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 233 (delta 100), reused 188 (delta 56), pack-reused 0 (from 0)
# Receiving objects: 100% (233/233), 199.88 KiB | 18.17 MiB/s, done.
# Resolving deltas: 100% (100/100), done.

# %%
# %cd SentAlign

# %%
# !pip install -r requirements.txt

# %%
print(f"Current working directory:")
# !pwd
# Out:
# Current working directory:
# /content/SentAlign

# %%
print('Changing to previous directory...')
# %cd ..
print(f"New working directory:")
# !pwd
# Out:
# Changing to previous directory...
# /content
# New working directory:
# /content

# %%
# !git clone https://github.com/mdmahendri/isic-nace-diff-data
# Out:
# Cloning into 'isic-nace-diff-data'...
# remote: Enumerating objects: 1966, done.
# remote: Counting objects: 100% (1966/1966), done.
# remote: Compressing objects: 100% (1254/1254), done.
# remote: Total 1966 (delta 570), reused 1958 (delta 562), pack-reused 0 (from 0)
# Receiving objects: 100% (1966/1966), 1.48 MiB | 25.70 MiB/s, done.
# Resolving deltas: 100% (570/570), done.

# %%
# %cd SentAlign
# Out:
# /content/SentAlign

# %%
# !python3 files2align.py -dir 'input-sa' --source-language isic5
# Out:
# files2align.txt and filesdone.txt created in input-sa/
# Files to align: 1088
# Files already aligned: 0

# %%
# !python3 setup.py build_ext --inplace
# Out:
# Compiling anchoring.pyx because it changed.
# Compiling buffer_work_space.pyx because it changed.
# Compiling file_read_back.pyx because it changed.
# Compiling galechurch.pyx because it changed.
# Compiling greedy.pyx because it changed.
# Compiling utilities.pyx because it changed.
# [1/6] Cythonizing anchoring.pyx
# [2/6] Cythonizing buffer_work_space.pyx
# [3/6] Cythonizing file_read_back.pyx
# [4/6] Cythonizing galechurch.pyx
# [5/6] Cythonizing greedy.pyx
# [6/6] Cythonizing utilities.pyx

# %%
# !python3 sentAlign.py -dir 'input-sa' -sl isic5 -tl nace21
# Out:
# 2025-12-26 16:19:11.235545: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766765951.255735    3413 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766765951.261851    3413 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766765951.279966    3413 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !zip -r outputsa.zip input-sa
